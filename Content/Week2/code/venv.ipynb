# %% [markdown]
# check version
# ``` python --version ```
# or
# ``` python3 --version ```

# %% [markdown]
# Create a virtual environment ``` python -m venv myenv ```

# %% [markdown]
# myenv/
# │
# ├── Include/
# ├── Lib/
# ├── Scripts/      ← (Windows)
# └── bin/          ← (Linux / macOS)

# %% [markdown]
# On Windows: ``` myenv\Scripts\activate```

# %% [markdown]
# On Linux / macOS:
# ``` source myenv/bin/activate ```

# %% [markdown]
# After activation, your terminal will show: ``` (myenv) C:\Users\Ahmed\project>```

# %% [markdown]
# Installing Packages  ``` pip install pandas numpy matplotlib```

# %% [markdown]
# To check installed packages:  ``` pip list ```

# %% [markdown]
# Saving at requirements.txt  ``` pip freeze > requirements.txt```

# %% [markdown]
# How to Clonw project with venv
# ``` bash
# python -m venv myenv
# source myenv/bin/activate
# pip install -r requirements.txt
# ```

# %% [markdown]
# To deactivate  ``` deactivate ```

# %% [markdown]
# To delete rm ``` -rf myenv ```
